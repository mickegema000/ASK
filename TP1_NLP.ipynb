# %% [markdown]
# <a href="https://colab.research.google.com/github/mickegema000/ASK/blob/main/TP1_NLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install numpy pandas scikit-learn nltk spacy gensim

import nltk
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# ...
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
 from sklearn . datasets import fetch_20newsgroups
 import pandas as pd
 # Chargement d'un sous-ensemble du 20 newsgroups
categories = ['sci.space', 'rec.autos']
data = fetch_20newsgroups(subset='train', categories=categories, remove=('headers', 'footers', 'quotes'))
corpus = data.data
# Conversion en DataFrame pour plus de confort
df = pd.DataFrame({'text': corpus, 'target': data.target})
df
# Out:
#                                                    text  target
# 0     Well thank you dennis for your as usual highly...       1
# 1     \n\nPerhaps a nice used '88 Pontiac Fiero GT? ...       0
# 2     I bought a car with a defunct engine, to use f...       0
# 3     \nI haven't seen any speculation about it. But...       1
# 4     I am in the process of looking for a half dece...       0
# ...                                                 ...     ...
# 1182  As for SF and advertising in space. There is a...       1
# 1183  Could we plase cease this discussion.  I fail ...       0
# 1184  \nNope, I haven't seen the film, but Taylor's ...       1
# 1185  I was lloking at the Geo Prizm Lsi today (very...       0
# 1186  I am interested in finding out how the 4Runner...       0
#
# [1187 rows x 2 columns]

# %%
# 2 Nettoyage et Prétraitement
import re
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

# %%
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

def preprocess_text(text):
    # Mise en minuscule
    text = text.lower()
    # Suppression de la ponctuation
    text = re.sub(r'[^a-zA-Z\s]', '', text)
df['clean_text'] = df['text'].apply(preprocess_text)
df
# Out:
#                                                    text  target clean_text
# 0     Well thank you dennis for your as usual highly...       1       None
# 1     \n\nPerhaps a nice used '88 Pontiac Fiero GT? ...       0       None
# 2     I bought a car with a defunct engine, to use f...       0       None
# 3     \nI haven't seen any speculation about it. But...       1       None
# 4     I am in the process of looking for a half dece...       0       None
# ...                                                 ...     ...        ...
# 1182  As for SF and advertising in space. There is a...       1       None
# 1183  Could we plase cease this discussion.  I fail ...       0       None
# 1184  \nNope, I haven't seen the film, but Taylor's ...       1       None
# 1185  I was lloking at the Geo Prizm Lsi today (very...       0       None
# 1186  I am interested in finding out how the 4Runner...       0       None
#
# [1187 rows x 3 columns]

# %%
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer(max_features=1000, stop_words='english')
X_bow = vectorizer.fit_transform(df['clean_text'])

# Affichage de la dimension de la matrice
print("Taille de la matrice BOW :", X_bow.shape)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-69-bb4a44c73282> in <cell line: 4>()
#       2
#       3 vectorizer = CountVectorizer(max_features=1000, stop_words='english')
# ----> 4 X_bow = vectorizer.fit_transform(df['clean_text'])
#       5
#       6 # Affichage de la dimension de la matrice
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1471                 )
#    1472             ):
# -> 1473                 return fit_method(estimator, *args, **kwargs)
#    1474
#    1475         return wrapper
#
# /usr/local/lib/python3.10/dist-packages/sklearn/feature_extraction/text.py in fit_transform(self, raw_documents, y)
#    1370                     break
#    1371
# -> 1372         vocabulary, X = self._count_vocab(raw_documents, self.fixed_vocabulary_)
#    1373
#    1374         if self.binary:
#
# ...

# %%
vectorizer_onehot = CountVectorizer(binary = True)
X_onehot = vectorizer_onehot.fit_transform(df['clean_text'])
print("Taille de la matrice One - Hot :", X_onehot.shape)
# Out:
# Taille de la matrice One - Hot : (1187, 17056)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer()
X_tfidf = tfidf.fit_transform(df['clean_text'])
print("Taille de la matrice TF-IDF :", X_tfidf.shape)
# Out:
# Taille de la matrice TF-IDF : (1187, 17056)

# %%
bigram_vectorizer = CountVectorizer(ngram_range=(1, 2))
X_bigrams = bigram_vectorizer.fit_transform(df['clean_text'])
print("Taille de la matrice avec bigrams :", X_bigrams.shape)
# Out:
# Taille de la matrice avec bigrams : (1187, 118843)

# %%
# !pip install nltk
import nltk

#
nltk.download('punkt_tab')

# Preparation des phrases
def tokenize_text(text):
    tokens = nltk.word_tokenize(text)
    return tokens

sentences = [tokenize_text(text) for text in df['clean_text']]

# Entrainement du modele
from gensim.models import Word2Vec # Assurez-vous que gensim est installé : !pip install gensim
model = Word2Vec(sentences, vector_size=100, window=5, min_count=5, workers=4)

# Acces au vecteur d’un mot :
try:
    print(model.wv['space']) # Par exemple, si le mot 'space' est dans le vocabulaire
except KeyError:
    print("The word 'space' is not in the vocabulary.")
# Out:
# ...
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [-0.7646365   0.27797613  0.09541585  0.06565295  0.16151734 -0.49000338
#  -0.24886382  0.766088    0.17642452  0.03368798  0.56364274 -0.8445533
#  -0.27117425 -0.06886007  0.26687673 -0.89904064  0.6301531  -0.8957987
#   0.20802046 -0.651999    0.67234516 -0.54278815 -0.00249831 -0.06386457
#   0.15738155 -0.56432813 -0.3715037   0.6927664  -0.24185772 -0.5698358
#   1.4244014  -0.22636893 -0.81979024 -0.44806534 -0.6443248   0.483663
#   0.7825485  -0.40681723 -0.01511263 -0.4625181   0.16404167  0.35580415
#  -0.44706392 -0.2925849  -0.48115692  0.5263743  -0.81115174  0.8667541
#   0.13991146  0.57377523  0.06771451 -0.12114054  0.08611979  0.34464693
#  -1.0746329  -0.02040361  0.96844023 -0.02813493 -0.7274245  -0.01626176
#   0.12974812  0.4654219  -0.51072335 -0.4587498  -0.32638893 -0.618144
# ...
